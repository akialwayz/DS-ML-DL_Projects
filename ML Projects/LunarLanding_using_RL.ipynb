# %%
#Installing Necessary Dependancies
# !apt install swig cmake
# !pip install -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt
    
#Install Packagess for rendering the scene
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# swig is already the newest version (3.0.12-1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.8/dist-packages (from -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.6.2)
# Requirement already satisfied: box2d in /usr/local/lib/python3.8/dist-packages (from -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 2)) (2.3.10)
# Requirement already satisfied: box2d-kengz in /usr/local/lib/python3.8/dist-packages (from -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 3)) (2.3.3)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.8/dist-packages (from -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (2.2.4)
# Requirement already satisfied: pyglet==1.5.1 in /usr/local/lib/python3.8/dist-packages (from -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 5)) (1.5.1)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.8/dist-packages (from huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (2.2.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.8/dist-packages (from huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (0.11.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.8/dist-packages (from huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (0.10.1)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.8/dist-packages (from huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (3.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 4)) (2022.9.24)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (3.2.2)
# Requirement already satisfied: importlib-metadata~=4.13 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (4.13.0)
# Requirement already satisfied: gym==0.21 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.21.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.3.5)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.13.0+cu116)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2.9.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (7.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (4.6.0.66)
# Requirement already satisfied: ale-py==0.7.4 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.7.4)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.4.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (12.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (5.4.8)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from ale-py==0.7.4->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (5.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (7.1.2)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata~=4.13->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (3.11.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2.15.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (3.19.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.51.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (3.2.2)
# Requirement already satisfied: libtorrent in /usr/local/lib/python3.8/dist-packages (from AutoROM.accept-rom-license->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2022.6)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (2.6.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich->stable-baselines3[extra]->-r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt (line 1)) (0.9.1)
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Fetched 264 kB in 1s (303 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.13).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.8/dist-packages (3.0)

# %%
# Kill Server To get Render to work
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# Importing all dependancies
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login # To log into Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
import gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, done and info
  observation, reward, done, info = env.step(action)
  
  # If the game is done (in our case we land, crashed or timeout)
  if done:
      # Reset the environment
      print("Environment is reset")
      observation = env.reset()
# Out:
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 0
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 3

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.842088    0.60697955 -0.58911    -0.3151298   0.70200133  0.541374
#   0.5813573  -0.45574722]
#
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 0

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 2048,
    batch_size = 64,
    n_epochs = 10,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1790000)
# Save the model
model_name = "akilsver_ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.7     |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    fps             | 3740     |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.7        |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1648        |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007756427 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 3.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1387        |
# |    iterations           | 3           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009140601 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0205     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 485         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 974         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.5        |
# |    ep_rew_mean          | -81.8       |
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 4           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008967102 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0116     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 221         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 552         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.6        |
# |    ep_rew_mean          | -61.6       |
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013172586 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 3.39e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 298         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | -47.4      |
# | time/                   |            |
# |    fps                  | 1187       |
# |    iterations           | 6          |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.01032655 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.000453   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 89         |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00943   |
# |    value_loss           | 241        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -37         |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 7           |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.009961402 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -8.94e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 255         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 145        |
# |    ep_rew_mean          | -18.7      |
# | time/                   |            |
# |    fps                  | 1130       |
# |    iterations           | 8          |
# |    time_elapsed         | 231        |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.01024606 |
# |    clip_fraction        | 0.0899     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.000854   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 157        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00659   |
# |    value_loss           | 360        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -8.75       |
# | time/                   |             |
# |    fps                  | 1096        |
# |    iterations           | 9           |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.009935602 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.0696     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 299         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 475         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -4.8        |
# | time/                   |             |
# |    fps                  | 1030        |
# |    iterations           | 10          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.008512946 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.0172     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 301         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 620         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | 3.9         |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 11          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.009554287 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.00776    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 358         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | 21.6        |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 12          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.005854872 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 218         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 256         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 643          |
# |    ep_rew_mean          | 39.7         |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 13           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0061177965 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.5         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 145          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 649          |
# |    ep_rew_mean          | 45           |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 14           |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0047487672 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 166          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 709        |
# |    ep_rew_mean          | 61.4       |
# | time/                   |            |
# |    fps                  | 825        |
# |    iterations           | 15         |
# |    time_elapsed         | 595        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.00395633 |
# |    clip_fraction        | 0.0273     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.826      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 47.5       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00264   |
# |    value_loss           | 126        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 743         |
# |    ep_rew_mean          | 78.4        |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 16          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.004710172 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 94.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 806          |
# |    ep_rew_mean          | 99.1         |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 17           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0037746725 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 66.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 866         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 18          |
# |    time_elapsed         | 760         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.006016506 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 46.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 904         |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 19          |
# |    time_elapsed         | 814         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.007908167 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.55        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 898         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 20          |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.005985398 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.51        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 37.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 21          |
# |    time_elapsed         | 922         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004556367 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 51.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 22          |
# |    time_elapsed         | 978         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.004024793 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.98        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 729          |
# |    iterations           | 23           |
# |    time_elapsed         | 1032         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0046666563 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000876    |
# |    value_loss           | 29.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 896          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 24           |
# |    time_elapsed         | 1084         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0045178887 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 21.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 25           |
# |    time_elapsed         | 1140         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0034854147 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 61.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 26           |
# |    time_elapsed         | 1192         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0050610183 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 4.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 27           |
# |    time_elapsed         | 1244         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0048563266 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.615        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 6.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 28           |
# |    time_elapsed         | 1297         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0030829697 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.732        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 11.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 984         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 29          |
# |    time_elapsed         | 1350        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.009483799 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.359       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 986        |
# |    ep_rew_mean          | 159        |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 30         |
# |    time_elapsed         | 1400       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.00773527 |
# |    clip_fraction        | 0.0353     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.321      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00228   |
# |    value_loss           | 1.01       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 974          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 31           |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0074580004 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.366        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 20.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 32           |
# |    time_elapsed         | 1498         |
# |    total_timesteps      | 1048576      |
# | train/                  |              |
# |    approx_kl            | 0.0045189788 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.326        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 25.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 885         |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 33          |
# |    time_elapsed         | 1546        |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.003551904 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000553   |
# |    value_loss           | 102         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 843          |
# |    ep_rew_mean          | 188          |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 34           |
# |    time_elapsed         | 1593         |
# |    total_timesteps      | 1114112      |
# | train/                  |              |
# |    approx_kl            | 0.0049822247 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.2         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 90.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 757          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 35           |
# |    time_elapsed         | 1638         |
# |    total_timesteps      | 1146880      |
# | train/                  |              |
# |    approx_kl            | 0.0053455234 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.31         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 584         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 36          |
# |    time_elapsed         | 1682        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.005212983 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 197         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 273         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 440         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 37          |
# |    time_elapsed         | 1724        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.005071602 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 174         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 388         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 38           |
# |    time_elapsed         | 1764         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0068549467 |
# |    clip_fraction        | 0.0927       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 196          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 332          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 39          |
# |    time_elapsed         | 1800        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.011166565 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 229         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 40          |
# |    time_elapsed         | 1837        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.007903494 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 189         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 41           |
# |    time_elapsed         | 1874         |
# |    total_timesteps      | 1343488      |
# | train/                  |              |
# |    approx_kl            | 0.0037730746 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.4         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 231          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 42           |
# |    time_elapsed         | 1911         |
# |    total_timesteps      | 1376256      |
# | train/                  |              |
# |    approx_kl            | 0.0037337653 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 153          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000983    |
# |    value_loss           | 204          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 248        |
# |    ep_rew_mean          | 272        |
# | time/                   |            |
# |    fps                  | 723        |
# |    iterations           | 43         |
# |    time_elapsed         | 1947       |
# |    total_timesteps      | 1409024    |
# | train/                  |            |
# |    approx_kl            | 0.00331139 |
# |    clip_fraction        | 0.0277     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.732     |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.6       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.000847  |
# |    value_loss           | 176        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 44          |
# |    time_elapsed         | 1983        |
# |    total_timesteps      | 1441792     |
# | train/                  |             |
# |    approx_kl            | 0.004425039 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 83.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 45           |
# |    time_elapsed         | 2019         |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0033015227 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000691    |
# |    value_loss           | 62.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 46           |
# |    time_elapsed         | 2055         |
# |    total_timesteps      | 1507328      |
# | train/                  |              |
# |    approx_kl            | 0.0042463676 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0008      |
# |    value_loss           | 43.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 47          |
# |    time_elapsed         | 2091        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.004684595 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.83        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 12.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 279          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 48           |
# |    time_elapsed         | 2129         |
# |    total_timesteps      | 1572864      |
# | train/                  |              |
# |    approx_kl            | 0.0039153704 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 49           |
# |    time_elapsed         | 2164         |
# |    total_timesteps      | 1605632      |
# | train/                  |              |
# |    approx_kl            | 0.0043373015 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.21         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 100          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 50           |
# |    time_elapsed         | 2199         |
# |    total_timesteps      | 1638400      |
# | train/                  |              |
# |    approx_kl            | 0.0032988973 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.1          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 171          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 271         |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 51          |
# |    time_elapsed         | 2234        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.004786037 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 401         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 52          |
# |    time_elapsed         | 2268        |
# |    total_timesteps      | 1703936     |
# | train/                  |             |
# |    approx_kl            | 0.003302241 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.4        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.000654   |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 53           |
# |    time_elapsed         | 2303         |
# |    total_timesteps      | 1736704      |
# | train/                  |              |
# |    approx_kl            | 0.0039521903 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 227          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 54           |
# |    time_elapsed         | 2338         |
# |    total_timesteps      | 1769472      |
# | train/                  |              |
# |    approx_kl            | 0.0033517652 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000744    |
# |    value_loss           | 183          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 55           |
# |    time_elapsed         | 2372         |
# |    total_timesteps      | 1802240      |
# | train/                  |              |
# |    approx_kl            | 0.0040276228 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.671       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.87         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000612    |
# |    value_loss           | 123          |
# ------------------------------------------

# %%
# Evaluation or model
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=60, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=280.65 +/- 20.015303384743916

# %%
# Logining to HuggingFace to commit model
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance 
## CHANGE WITH YOUR REPO ID
repo_id = "akialwayz/ppo-LunarLander-v2" 

## Define the commit message
commit_message = "2nd Version of PPO LunarLander-v2 trained agent"

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance 
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmppq49y_o9/-step-0-to-step-1000.mp4
# ℹ Pushing repo akialwayz/ppo-LunarLander-v2 to the Hugging Face Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/akialwayz/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/akialwayz/ppo-LunarLander-v2/tree/main/'

# %%
from huggingface_sb3 import load_from_hub
repo_id = "akialwayz/ppo-LunarLander-v2" # The repo_id
filename = "akilsver_ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# Downloading:   0%|          | 0.00/147k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# OS: Linux-5.10.133+-x86_64-with-glibc2.27 #1 SMP Fri Aug 26 08:44:51 UTC 2022
# Python: 3.8.16
# Stable-Baselines3: 1.6.2
# PyTorch: 1.13.0+cu116
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.10.133+-x86_64-with-glibc2.27 #1 SMP Fri Aug 26 08:44:51 UTC 2022
# Python: 3.8.16
# Stable-Baselines3: 1.6.2
# PyTorch: 1.13.0+cu116
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=282.52 +/- 10.006976618862987
